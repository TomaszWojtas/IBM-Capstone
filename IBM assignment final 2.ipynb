# %% [markdown]
# # Introduction
# The aim of this document is to look at theatre in Warsaw and answer questions:
# 1. Is there any relation between rating of the theatre and number of venues around?
# 2. Is there any relation between popularity of the theatre and number of venues around?
# This issues can be important when you want to establish your own theatre.
#
# # Data
# Data for this paper was downloaded from wikipedia. There is an article in polish about theatres in Warsaw and this article has table of places with adresses. Basic on this table using googlemaps specific latitude and longitude was collected. After that each location was scoped using foursquare in 500m around to find places in each location.
#
# # Methodology
# Collected data was cleaned, scoped, summarised in many ways to zoom the structure. It was also shown on the folium map where each theatre is located. After that linear regression models were performed to find answer to the questions.
#
# # Results
# I found no relation between rating and number of venues around. I found also no relation between popularity of ratings and venues around. It seems that popularity and rating of the teatre depends on diffrent factors (like actors, plays, director, etc.) which were not included in this research.
#
# # Conclusions
# Before final conclusion there i think it's worth to look for type of venues and rating and popularity (in fact this was the main purpose of this analysis). Unfortunately, foursquare classifies too many types of venues (around 200) and it can't be used to include 200 predictors in model with 50 observations.

# %%
import pandas as pd
import numpy as np
import json
from bs4 import BeautifulSoup
from matplotlib import pyplot as plt
from matplotlib import colors as colors
import sklearn.cluster
import folium
import requests
from IPython.display import clear_output
import googlemaps

# %%
url_theatres = "https://pl.wikipedia.org/wiki/Teatry_w_Warszawie"
theatres = requests.get(url_theatres).text

soup = BeautifulSoup(theatres)
table = soup.find_all('table')[0]
t_df = pd.read_html(str(table))[0]
t_df.drop(columns = ['Unnamed: 5'], inplace=True)
t_df
# Out:
#                                  teatr             rodzaj  \
# 0   Mazowiecki Teatr Muzyczny Operetka   teatr operetkowy
# 1                           Nowy Teatr  teatr dramatyczny
# 2                            Och-Teatr  teatr dramatyczny
# 3                    Stara ProchOFFnia                NaN
# 4                         Studio Buffo     teatr muzyczny
# 5                    Studium Teatralne                NaN
# 6                      Teatr 6. piętro  teatr dramatyczny
# 7                        Teatr Ateneum  teatr dramatyczny
# 8                            Teatr Baj        teatr lalek
# 9                          Teatr Bajka    teatr komediowy
# 10                     Teatr „Capitol”    teatr komediowy
# 11            Teatr Collegium Nobilium  teatr dramatyczny
# 12    Teatr Dramatyczny m.st. Warszawy  teatr dramatyczny
# 13                  Teatr Druga Strefa  teatr dramatyczny
# 14                       Teatr Guliwer        teatr lalek
# 15                          Teatr IMKA  teatr dramatyczny
# 16                     Teatr Kamienica    teatr komediowy
# 17                       Teatr Komedia    teatr komediowy
# 18                       Teatr Kwadrat    teatr komediowy
# 19                         Teatr Lalka    teatr familijny
# 20                  Teatr Małego Widza    teatr dziecięcy
# 21                     Teatr Montownia  teatr dramatyczny
# 22               Teatr Muzyczny „Roma”     teatr muzyczny
# 23                       Teatr na Woli  teatr dramatyczny
# 24                      Teatr Narodowy  teatr dramatyczny
# 25                        Teatr Ochoty  teatr dramatyczny
# 26                     Teatr „Polonia”  teatr dramatyczny
# 27                        Teatr Polski  teatr dramatyczny
# 28                    Teatr Powszechny  teatr dramatyczny
# 29                         Teatr Praga                NaN
# 30                        Teatr Praski                NaN
# 31                         Teatr Rampa                NaN
# 32                   Teatr Rozmaitości  teatr dramatyczny
# 33                         Teatr Sabat     teatr muzyczny
# 34             Teatr Scena Prezentacje  teatr dramatyczny
# 35                  Teatr Staromiejski                NaN
# 36                        Teatr Studio  teatr dramatyczny
# 37                        Teatr Syrena    teatr komediowy
# 38       Teatr Wielki - Opera Narodowa      teatr operowy
# 39                       Teatr WARSawy   teatr niezależny
# 40                   Teatr Wolandejski  teatr dramatyczny
# 41                   Teatr Współczesny  teatr dramatyczny
# 42                     Teatr Wytwórnia       teatr offowy
# 43                     Teatr Za Daleki                NaN
# 44                      Teatr Żydowski  teatr dramatyczny
# 45          Warszawska Opera Kameralna      teatr operowy
#
#                                            prowadzący  \
# 0                                   Włodzimierz Izban
# 1                               Krzysztof Warlikowski
# 2   Katarzyna Błachiewicz (dyrektor teatrów Fundac...
# 3                                  Wojciech Feliksiak
# 4   Janusz Stokłosa (prezes), Janusz Józefowicz (d...
# 5                                                 NaN
# 6                  Michał Żebrowski i Eugeniusz Korin
# 7                                      Ryszard Markow
# 8                                      Ewa Piotrowska
# 9                          Natalia Pietkiewicz-Szwarc
# 10               Anna Gornostaj i Stanisław Mączyński
# 11                                    Jarosław Kilian
# 12                               Tadeusz Słobodzianek
# 13                                   Sylwester Biraga
# 14  Mirosław Korzeb (dyrektor), Robert Jarosz (kie...
# 15                                     Tomasz Karolak
# 16                                   Emilian Kamiński
# 17                                  Tomasz Dutkiewicz
# 18                                     Andrzej Nejman
# 19                                    Jarosław Kilian
# 20                                Agnieszka Czekierda
# 21  Adam Krawczuk, Marcin Perchuć, Rafał Rutkowski...
# 22                                Wojciech Kępczyński
# 23                               Tadeusz Słobodzianek
# 24                                        Jan Englert
# 25                                    Joanna Nawrocka
# 26  Katarzyna Błachiewicz (dyrektor teatrów Fundac...
# 27                 Jarosław Gajewski (p.o. dyrektora)
# 28                                       Jan Buchwald
# 29                                 Monika Wielogórska
# 30                                      Marcin Kwaśny
# 31  Witold Olejarz (dyrektor naczelny), Jan Prochy...
# 32                                   Grzegorz Jarzyna
# 33                                 Małgorzata Potocka
# 34                                      Romuald Szejd
# 35  Natalia Fijewska-Zdanowska, Zuzanna, Agata Fij...
# 36  Maciej Klimczak (dyrektor naczelny), Agnieszka...
# 37                                  Jacek Mikołajczyk
# 38  Waldemar Dąbrowski (dyrektor naczelny), Marius...
# 39                                        Adam Sajnuk
# 40                                    Piotr Kulczycki
# 41                                     Maciej Englert
# 42                                 Małgorzata Owsiany
# 43                                   Dariusz Sitterle
# 44                                       Gołda Tencer
# 45                                   Stefan Sutkowski
#
#                                              siedziba  \
# 0                          Bielany, ul. Kolumbijska 3
# 1                    Mokotów, ul. Madalińskiego 10/16
# 2                             Ochota, ul. Grójecka 65
# 3                           Śródmieście, ul. Boleść 2
# 4                     Śródmieście, ul. Konopnickiej 6
# 5                  Praga-Południe, ul. Lubelska 30/32
# 6   Śródmieście, Pałac Kultury i Nauki – wejście o...
# 7                          Śródmieście, ul. Jaracza 2
# 8                   Praga-Północ, ul. Jagiellońska 28
# 9                  Śródmieście, ul. Marszałkowska 138
# 10                 Śródmieście, ul. Marszałkowska 115
# 11                     Śródmieście, ul. Miodowa 22/24
# 12                 Śródmieście, Pałac Kultury i Nauki
# 13                        Mokotów, ul. Magazynowa 14a
# 14                             Mokotów, ul. Różana 16
# 15                    Śródmieście, ul. Konopnickiej 6
# 16    Śródmieście, kamienica przy Al. Solidarności 93
# 17                      Żoliborz, ul. Słowackiego 19a
# 18                   Śródmieście, ul. Czackiego 15/17
# 19  Śródmieście, Pałac Kultury i Nauki – wejście o...
# 20  Śródmieście, ul. Jezuicka 4 (wejście od ul. Br...
# 21                    Śródmieście, ul. Konopnickiej 6
# 22                    Śródmieście, ul. Nowogrodzka 49
# 23                             Wola, ul. Kasprzaka 22
# 24         Śródmieście, Teatr Wielki; ul. Wierzbowa 3
# 25                                 Ochota, ul. Reja 9
# 26                     Śródmieście, ul. Marszałkowska
# 27                         Śródmieście, ul. Karasia 2
# 28                 Praga-Południe, ul. Zamoyskiego 20
# 29                       Praga-Północ, ul. Otwocka 14
# 30                          Praga-Północ, ul. Kępna 6
# 31                            Targówek, ul. Kołowa 20
# 32                     Śródmieście, ul. Marszałkowska
# 33                         Śródmieście, ul. Foksal 16
# 34                            Wola, ul. Żelazna 51/53
# 35                        Śródmieście, ul. Jezuicka 4
# 36                 Śródmieście, Pałac Kultury i Nauki
# 37                        Śródmieście, ul. Litewska 3
# 38         Śródmieście, Teatr Wielki - Opera Narodowa
# 39                              Rynek Nowego Miasta 5
# 40                           Stokłosy, ul. Lachmana 5
# 41                     Śródmieście, ul. Mokotowska 13
# 42                     Praga-Północ, ul. Markowska 18
# 43                          Ursynów, ul. Wiolinowa 14
# 44                   Śródmieście, ulica Senatorska 35
# 45              Śródmieście, aleja „Solidarności” 76b
#
#                              www
# 0                  www.mteatr.pl
# 1              www.nowyteatr.org
# 2            www.ochteatr.com.pl
# 3   www.staraprochoffnia.scek.pl
# 4         www.studiobuffo.com.pl
# 5        www.studiumteatralne.pl
# 6            www.teatr6pietro.pl
# 7            www.teatrateneum.pl
# 8            www.teatrbaj.waw.pl
# 9              www.teatrbajka.pl
# 10           www.teatrcapitol.pl
# 11                 www.at.edu.pl
# 12       www.teatrdramatyczny.pl
# 13       www.teatrdrugastrefa.pl
# 14       www.teatrguliwer.waw.pl
# 15             www.teatr-imka.pl
# 16         www.teatrkamienica.pl
# 17           www.teatrkomedia.pl
# 18           www.teatrkwadrat.pl
# 19            www.teatrlalka..pl
# 20       www.teatrmalegowidza.pl
# 21         www.teatrmontownia.pl
# 22         www.teatrmuzyczny.com
# 23       www.teatrdramatyczny.pl
# 24               www.narodowy.pl
# 25            www.teatrochoty.pl
# 26           www.teatrpolonia.pl
# 27       www.teatr-polski.art.pl
# 28         www.powszechny.art.pl
# 29             www.teatrpraga.pl
# 30            www.teatrpraski.eu
# 31            www.teatr-rampa.pl
# 32             www.trwarszawa.pl
# 33            www.teatr-sabat.pl
# 34       www.teatrprezentacje.pl
# 35      www.teatrstaromiejski.pl
# 36            www.teatrstudio.pl
# 37            www.teatrsyrena.pl
# 38            www.teatrwielki.pl
# 39       http://teatrwarsawy.pl/
# 40            www.wolandejski.pl
# 41            www.wspolczesny.pl
# 42         www.teatrwytwornia.pl
# 43          www.domsztuki.art.pl
# 44     www.teatr-zydowski.art.pl
# 45         www.operakameralna.pl

# %%
t_df['rodzaj'].value_counts().to_frame(name="Count")
# Out:
#                    Count
# teatr dramatyczny     21
# teatr komediowy        6
# teatr muzyczny         3
# teatr lalek            2
# teatr operowy          2
# teatr offowy           1
# teatr operetkowy       1
# teatr familijny        1
# teatr niezależny       1
# teatr dziecięcy        1

# %%
# Out:
#                                  teatr             rodzaj  \
# 0   Mazowiecki Teatr Muzyczny Operetka   teatr operetkowy
# 1                           Nowy Teatr  teatr dramatyczny
# 2                            Och-Teatr  teatr dramatyczny
# 3                    Stara ProchOFFnia                NaN
# 4                         Studio Buffo     teatr muzyczny
# 5                    Studium Teatralne                NaN
# 6                      Teatr 6. piętro  teatr dramatyczny
# 7                        Teatr Ateneum  teatr dramatyczny
# 8                            Teatr Baj        teatr lalek
# 9                          Teatr Bajka    teatr komediowy
# 10                     Teatr „Capitol”    teatr komediowy
# 11            Teatr Collegium Nobilium  teatr dramatyczny
# 12    Teatr Dramatyczny m.st. Warszawy  teatr dramatyczny
# 13                  Teatr Druga Strefa  teatr dramatyczny
# 14                       Teatr Guliwer        teatr lalek
# 15                          Teatr IMKA  teatr dramatyczny
# 16                     Teatr Kamienica    teatr komediowy
# 17                       Teatr Komedia    teatr komediowy
# 18                       Teatr Kwadrat    teatr komediowy
# 19                         Teatr Lalka    teatr familijny
# 20                  Teatr Małego Widza    teatr dziecięcy
# 21                     Teatr Montownia  teatr dramatyczny
# 22               Teatr Muzyczny „Roma”     teatr muzyczny
# 23                       Teatr na Woli  teatr dramatyczny
# 24                      Teatr Narodowy  teatr dramatyczny
# 25                        Teatr Ochoty  teatr dramatyczny
# 26                     Teatr „Polonia”  teatr dramatyczny
# 27                        Teatr Polski  teatr dramatyczny
# 28                    Teatr Powszechny  teatr dramatyczny
# 29                         Teatr Praga                NaN
# 30                        Teatr Praski                NaN
# 31                         Teatr Rampa                NaN
# 32                   Teatr Rozmaitości  teatr dramatyczny
# 33                         Teatr Sabat     teatr muzyczny
# 34             Teatr Scena Prezentacje  teatr dramatyczny
# 35                  Teatr Staromiejski                NaN
# 36                        Teatr Studio  teatr dramatyczny
# 37                        Teatr Syrena    teatr komediowy
# 38       Teatr Wielki - Opera Narodowa      teatr operowy
# 39                       Teatr WARSawy   teatr niezależny
# 40                   Teatr Wolandejski  teatr dramatyczny
# 41                   Teatr Współczesny  teatr dramatyczny
# 42                     Teatr Wytwórnia       teatr offowy
# 43                     Teatr Za Daleki                NaN
# 44                      Teatr Żydowski  teatr dramatyczny
# 45          Warszawska Opera Kameralna      teatr operowy
#
#                                            prowadzący  \
# 0                                   Włodzimierz Izban
# 1                               Krzysztof Warlikowski
# 2   Katarzyna Błachiewicz (dyrektor teatrów Fundac...
# 3                                  Wojciech Feliksiak
# 4   Janusz Stokłosa (prezes), Janusz Józefowicz (d...
# 5                                                 NaN
# 6                  Michał Żebrowski i Eugeniusz Korin
# 7                                      Ryszard Markow
# 8                                      Ewa Piotrowska
# 9                          Natalia Pietkiewicz-Szwarc
# 10               Anna Gornostaj i Stanisław Mączyński
# 11                                    Jarosław Kilian
# 12                               Tadeusz Słobodzianek
# 13                                   Sylwester Biraga
# 14  Mirosław Korzeb (dyrektor), Robert Jarosz (kie...
# 15                                     Tomasz Karolak
# 16                                   Emilian Kamiński
# 17                                  Tomasz Dutkiewicz
# 18                                     Andrzej Nejman
# 19                                    Jarosław Kilian
# 20                                Agnieszka Czekierda
# 21  Adam Krawczuk, Marcin Perchuć, Rafał Rutkowski...
# 22                                Wojciech Kępczyński
# 23                               Tadeusz Słobodzianek
# 24                                        Jan Englert
# 25                                    Joanna Nawrocka
# 26  Katarzyna Błachiewicz (dyrektor teatrów Fundac...
# 27                 Jarosław Gajewski (p.o. dyrektora)
# 28                                       Jan Buchwald
# 29                                 Monika Wielogórska
# 30                                      Marcin Kwaśny
# 31  Witold Olejarz (dyrektor naczelny), Jan Prochy...
# 32                                   Grzegorz Jarzyna
# 33                                 Małgorzata Potocka
# 34                                      Romuald Szejd
# 35  Natalia Fijewska-Zdanowska, Zuzanna, Agata Fij...
# 36  Maciej Klimczak (dyrektor naczelny), Agnieszka...
# 37                                  Jacek Mikołajczyk
# 38  Waldemar Dąbrowski (dyrektor naczelny), Marius...
# 39                                        Adam Sajnuk
# 40                                    Piotr Kulczycki
# 41                                     Maciej Englert
# 42                                 Małgorzata Owsiany
# 43                                   Dariusz Sitterle
# 44                                       Gołda Tencer
# 45                                   Stefan Sutkowski
#
#                                              siedziba  \
# 0                          Bielany, ul. Kolumbijska 3
# 1                    Mokotów, ul. Madalińskiego 10/16
# 2                             Ochota, ul. Grójecka 65
# 3                           Śródmieście, ul. Boleść 2
# 4                     Śródmieście, ul. Konopnickiej 6
# 5                  Praga-Południe, ul. Lubelska 30/32
# 6   Śródmieście, Pałac Kultury i Nauki – wejście o...
# 7                          Śródmieście, ul. Jaracza 2
# 8                   Praga-Północ, ul. Jagiellońska 28
# 9                  Śródmieście, ul. Marszałkowska 138
# 10                 Śródmieście, ul. Marszałkowska 115
# 11                     Śródmieście, ul. Miodowa 22/24
# 12                 Śródmieście, Pałac Kultury i Nauki
# 13                        Mokotów, ul. Magazynowa 14a
# 14                             Mokotów, ul. Różana 16
# 15                    Śródmieście, ul. Konopnickiej 6
# 16    Śródmieście, kamienica przy Al. Solidarności 93
# 17                      Żoliborz, ul. Słowackiego 19a
# 18                   Śródmieście, ul. Czackiego 15/17
# 19  Śródmieście, Pałac Kultury i Nauki – wejście o...
# 20  Śródmieście, ul. Jezuicka 4 (wejście od ul. Br...
# 33            www.teatr-sabat.pl  52.233872  21.020713
# 34       www.teatrprezentacje.pl  52.232311  20.991985
# 35      www.teatrstaromiejski.pl  52.249534  21.013566
# 36            www.teatrstudio.pl  52.231838  21.005995
# 37            www.teatrsyrena.pl  52.216430  21.022132
# 38            www.teatrwielki.pl  52.243532  21.010664
# 39       http://teatrwarsawy.pl/  52.252505  21.008484
# 40            www.wolandejski.pl  52.156659  21.041218
# 41            www.wspolczesny.pl  52.219043  21.017095
# 42         www.teatrwytwornia.pl  52.255454  21.042674
# 43          www.domsztuki.art.pl  52.161379  21.027026
# 44     www.teatr-zydowski.art.pl  52.242697  21.005431
# 45         www.operakameralna.pl  52.244005  20.997275

# %%
def find_latlon2(address):
    try:
        search_location = googlemaps.Client(key = "AIzaSyAmrWggSZIp0VABpc2gMp9fD2JQN5WE7Yk").places(address)
        lat = search_location['results'][0]['geometry']['location']['lat']
        lon = search_location['results'][0]['geometry']['location']['lng']
        rating = search_location['results'][0]['rating']
        user_ratings_total = search_location['results'][0]['user_ratings_total']
    except:
        search_location = googlemaps.Client(key = "AIzaSyAmrWggSZIp0VABpc2gMp9fD2JQN5WE7Yk").geocode(address)
        lat = search_location[0]['geometry']['location']['lat']
        lon = search_location[0]['geometry']['location']['lng']
        rating = "NaN"
        user_ratings_total = "NaN"
    return({'lat': round(lat,7), 'lon': round(lon,7), 'rating': rating, 'user_ratings_total': user_ratings_total})



lst = []
for teatr, address in zip(t_df['teatr'], t_df['siedziba']):
    lst.append(find_latlon2(address + " " +  teatr))
lst
# Out:
# [{'lat': 52.2767531,
#   'lon': 20.9480547,
#   'rating': 4.5,
#   'user_ratings_total': 65},
#  {'lat': 52.2052251,
#   'lon': 21.0199031,
#   'rating': 4.7,
#   'user_ratings_total': 912},
#  {'lat': 52.214206,
#   'lon': 20.980168,
#   'rating': 4.7,
#   'user_ratings_total': 2299},
#  {'lat': 52.2520335,
#   'lon': 21.0118501,
#   'rating': 4.5,
#   'user_ratings_total': 105},
#  {'lat': 52.2281469,
#   'lon': 21.026145,
#   'rating': 4.2,
#   'user_ratings_total': 114},
#  {'lat': 52.2504595, 'lon': 21.0509099, 'rating': 4, 'user_ratings_total': 7},
#  {'lat': 52.2317616,
#   'lon': 21.0061014,
#   'rating': 4.7,
#   'user_ratings_total': 1323},
#  {'lat': 52.2373039,
#   'lon': 21.0328462,
#   'rating': 4.7,
#   'user_ratings_total': 916},
#  {'lat': 52.2523563,
#   'lon': 21.034443,
#   'rating': 4.7,
#   'user_ratings_total': 79},
#  {'lat': 52.2358644,
#   'lon': 21.0086243,
#   'rating': 4.8,
#   'user_ratings_total': 2114},
#  {'lat': 52.2412061,
#   'lon': 21.0030915,
#   'rating': 4.6,
#   'user_ratings_total': 2563},
#  {'lat': 52.2486241,
#   'lon': 21.0079363,
#   'rating': 4.5,
#   'user_ratings_total': 21},
#  {'lat': 52.231311,
#   'lon': 21.007571,
#   'rating': 4.7,
#   'user_ratings_total': 407},
#  {'lat': 52.1862106,
#   'lon': 21.0054782,
#   'rating': 4.4,
#   'user_ratings_total': 86},
#  {'lat': 52.203143,
#   'lon': 21.019801,
#   'rating': 4.6,
#   'user_ratings_total': 389},
#  {'lat': 52.2284013,
#   'lon': 21.0261534,
#   'rating': 4.2,
#   'user_ratings_total': 535},
#  {'lat': 52.2432744,
#   'lon': 20.9984949,
#   'rating': 4.7,
#   'user_ratings_total': 1423},
#  {'lat': 52.2689536,
#   'lon': 20.9786279,
#   'rating': 4.7,
#   'user_ratings_total': 2101},
#  {'lat': 52.2358644,
#   'lon': 21.0086243,
#   'rating': 4.8,
#   'user_ratings_total': 2114},
#  {'lat': 52.2328725,
#   'lon': 21.0065461,
#   'rating': 4.5,
#   'user_ratings_total': 180},
#  {'lat': 52.249697,
#   'lon': 21.0139989,
#   'rating': 4.8,
#   'user_ratings_total': 335},
#  {'lat': 52.2284013,
#   'lon': 21.0261534,
#   'rating': 4.2,
#   'user_ratings_total': 535},
#  {'lat': 52.227404,
#   'lon': 21.007815,
#   'rating': 4.7,
#   'user_ratings_total': 5592},
#  {'lat': 52.2290795,
#   'lon': 20.9704782,
#   'rating': 4.7,
#   'user_ratings_total': 459},
#  {'lat': 52.242613,
#   'lon': 21.009646,
#   'rating': 4.8,
#   'user_ratings_total': 125},
#  {'lat': 52.2171578,
#   'lon': 20.9890375,
#   'rating': 4.6,
#   'user_ratings_total': 211},
#  {'lat': 52.22376,
#   'lon': 21.015918,
#   'rating': 4.7,
#   'user_ratings_total': 1032},
#  {'lat': 52.2385255,
#   'lon': 21.0197007,
#   'rating': 4.7,
#   'user_ratings_total': 92},
#  {'lat': 52.2471671,
#   'lon': 21.0481498,
#   'rating': 4.3,
#   'user_ratings_total': 734},
#  {'lat': 52.2591534, 'lon': 21.036559, 'rating': 4.3, 'user_ratings_total': 8},
#  {'lat': 52.2504689, 'lon': 21.0383497, 'rating': 0, 'user_ratings_total': 0},
#  {'lat': 52.2726599,
#   'lon': 21.049511,
#   'rating': 4.6,
#   'user_ratings_total': 1453},
#  {'lat': 52.214898,
#   'lon': 21.021133,
#   'rating': 4.5,
#   'user_ratings_total': 165},
#  {'lat': 52.233856,
#   'lon': 21.0208001,
#   'rating': 4.2,
#   'user_ratings_total': 477},
#  {'lat': 52.2323107, 'lon': 20.991985, 'rating': 4.8, 'user_ratings_total': 9},
#  {'lat': 52.249534, 'lon': 21.0135665, 'rating': 4.7, 'user_ratings_total': 3},
#  {'lat': 52.2324841,
#   'lon': 21.0067814,
#   'rating': 4.5,
#   'user_ratings_total': 238},
#  {'lat': 52.2163929,
#   'lon': 21.02207,
#   'rating': 4.6,
#   'user_ratings_total': 920},
#  {'lat': 52.2435324,
#   'lon': 21.0106636,
#   'rating': 4.8,
#   'user_ratings_total': 3751},
#  {'lat': 52.2525671,
#   'lon': 21.0084412,
#   'rating': 4.6,
#   'user_ratings_total': 253},
#  {'lat': 52.1566737,
#   'lon': 21.0412423,
#   'rating': 4.4,
#   'user_ratings_total': 30},
#  {'lat': 52.2189832,
#   'lon': 21.0171886,
#   'rating': 4.7,
#   'user_ratings_total': 730},
#  {'lat': 52.2554538,
#   'lon': 21.0426738,
#   'rating': 'NaN',
#   'user_ratings_total': 'NaN'},
#  {'lat': 52.1614393, 'lon': 21.026836, 'rating': 4, 'user_ratings_total': 4},
#  {'lat': 52.242686,
#   'lon': 21.0053911,
#   'rating': 4.4,
#   'user_ratings_total': 91},
#  {'lat': 52.2440049,
#   'lon': 20.9972748,
#   'rating': 4.5,
#   'user_ratings_total': 198}]

# %%
pd.DataFrame(lst)
# Out:
#           lat        lon rating user_ratings_total
# 0   52.276753  20.948055    4.5                 65
# 1   52.205225  21.019903    4.7                912
# 2   52.214206  20.980168    4.7               2299
# 3   52.252034  21.011850    4.5                105
# 4   52.228147  21.026145    4.2                114
# 5   52.250459  21.050910      4                  7
# 6   52.231762  21.006101    4.7               1323
# 7   52.237304  21.032846    4.7                916
# 8   52.252356  21.034443    4.7                 79
# 9   52.235864  21.008624    4.8               2114
# 10  52.241206  21.003092    4.6               2563
# 11  52.248624  21.007936    4.5                 21
# 12  52.231311  21.007571    4.7                407
# 13  52.186211  21.005478    4.4                 86
# 14  52.203143  21.019801    4.6                389
# 15  52.228401  21.026153    4.2                535
# 16  52.243274  20.998495    4.7               1423
# 17  52.268954  20.978628    4.7               2100
# 18  52.235864  21.008624    4.8               2114
# 19  52.232872  21.006546    4.5                180
# 20  52.249697  21.013999    4.8                335
# 21  52.228401  21.026153    4.2                535
# 22  52.227404  21.007815    4.7               5592
# 23  52.229079  20.970478    4.7                459
# 24  52.242613  21.009646    4.8                125
# 25  52.217158  20.989037    4.6                211
# 26  52.223760  21.015918    4.7               1032
# 27  52.238525  21.019701    4.7                 92
# 28  52.247167  21.048150    4.3                734
# 29  52.259153  21.036559    4.3                  8
# 30  52.250469  21.038350      0                  0
# 31  52.272660  21.049511    4.6               1453
# 32  52.214898  21.021133    4.5                165
# 33  52.233856  21.020800    4.2                477
# 34  52.232311  20.991985    4.8                  9
# 35  52.249534  21.013566    4.7                  3
# 36  52.232484  21.006781    4.5                238
# 37  52.216393  21.022070    4.6                920
# 38  52.243532  21.010664    4.8               3750
# 39  52.252567  21.008441    4.6                253
# 40  52.156674  21.041242    4.4                 30
# 41  52.218983  21.017189    4.7                730
# 42  52.255454  21.042674    NaN                NaN
# 43  52.161439  21.026836      4                  4
# 44  52.242686  21.005391    4.4                 91
# 45  52.244005  20.997275    4.5                198

# %%
t_full = pd.concat([t_df, pd.DataFrame(lst)], axis=1)

# %%
t_full = t_full[t_full['rating']!="NaN"]
# Out:
#                                  teatr             rodzaj  \
# 0   Mazowiecki Teatr Muzyczny Operetka   teatr operetkowy
# 1                           Nowy Teatr  teatr dramatyczny
# 2                            Och-Teatr  teatr dramatyczny
# 3                    Stara ProchOFFnia                NaN
# 4                         Studio Buffo     teatr muzyczny
# 5                    Studium Teatralne                NaN
# 27                 Jarosław Gajewski (p.o. dyrektora)
# 28                                       Jan Buchwald
# 29                                 Monika Wielogórska
# 30                                      Marcin Kwaśny
# 31  Witold Olejarz (dyrektor naczelny), Jan Prochy...
# 32                                   Grzegorz Jarzyna
# 33                                 Małgorzata Potocka
# 34                                      Romuald Szejd
# 35  Natalia Fijewska-Zdanowska, Zuzanna, Agata Fij...
# 36  Maciej Klimczak (dyrektor naczelny), Agnieszka...
# 37                                  Jacek Mikołajczyk
# 38  Waldemar Dąbrowski (dyrektor naczelny), Marius...
# 39                                        Adam Sajnuk
# 40                                    Piotr Kulczycki
# 41                                     Maciej Englert
# 43                                   Dariusz Sitterle
# 44                                       Gołda Tencer
# 45                                   Stefan Sutkowski
#
#                                              siedziba  \
# 0                          Bielany, ul. Kolumbijska 3
# 1                    Mokotów, ul. Madalińskiego 10/16
# 2                             Ochota, ul. Grójecka 65
# 3                           Śródmieście, ul. Boleść 2
# 4                     Śródmieście, ul. Konopnickiej 6
# 5                  Praga-Południe, ul. Lubelska 30/32
# 6   Śródmieście, Pałac Kultury i Nauki – wejście o...
# 7                          Śródmieście, ul. Jaracza 2
# 8                   Praga-Północ, ul. Jagiellońska 28
# 9                  Śródmieście, ul. Marszałkowska 138
# 10                 Śródmieście, ul. Marszałkowska 115
# 11                     Śródmieście, ul. Miodowa 22/24
# 12                 Śródmieście, Pałac Kultury i Nauki
# 13                        Mokotów, ul. Magazynowa 14a
# 14                             Mokotów, ul. Różana 16
# 15                    Śródmieście, ul. Konopnickiej 6
# 16    Śródmieście, kamienica przy Al. Solidarności 93
# 17                      Żoliborz, ul. Słowackiego 19a
# 18                   Śródmieście, ul. Czackiego 15/17
# 19  Śródmieście, Pałac Kultury i Nauki – wejście o...
# 20  Śródmieście, ul. Jezuicka 4 (wejście od ul. Br...
# 21                    Śródmieście, ul. Konopnickiej 6
# 22                    Śródmieście, ul. Nowogrodzka 49
# 23                             Wola, ul. Kasprzaka 22
# 24         Śródmieście, Teatr Wielki; ul. Wierzbowa 3
# 25                                 Ochota, ul. Reja 9
# 26                     Śródmieście, ul. Marszałkowska
# 27                         Śródmieście, ul. Karasia 2
# 28                 Praga-Południe, ul. Zamoyskiego 20
# 29                       Praga-Północ, ul. Otwocka 14
# 30                          Praga-Północ, ul. Kępna 6
# 31                            Targówek, ul. Kołowa 20
# 32                     Śródmieście, ul. Marszałkowska
# 33                         Śródmieście, ul. Foksal 16
# 34                            Wola, ul. Żelazna 51/53
# 35                        Śródmieście, ul. Jezuicka 4
# 36                 Śródmieście, Pałac Kultury i Nauki
# 37                        Śródmieście, ul. Litewska 3
# 38         Śródmieście, Teatr Wielki - Opera Narodowa
# 39                              Rynek Nowego Miasta 5
# 40                           Stokłosy, ul. Lachmana 5
# 41                     Śródmieście, ul. Mokotowska 13
# 43                          Ursynów, ul. Wiolinowa 14
# 44                   Śródmieście, ulica Senatorska 35
# 45              Śródmieście, aleja „Solidarności” 76b
#
#                              www        lat        lon rating  \
# 16               1423
# 17               2101
# 18               2114
# 19                180
# 20                335
# 21                535
# 22               5592
# 23                459
# 24                125
# 25                211
# 26               1032
# 27                 92
# 28                734
# 29                  8
# 30                  0
# 31               1453
# 32                165
# 33                477
# 34                  9
# 35                  3
# 36                238
# 37                920
# 38               3751
# 39                253
# 40                 30
# 41                730
# 43                  4
# 44                 91
# 45                198

# %%
def db_gen(lat, lon, radius = 500, limit = 100):
  
    client_id = 'W0NOIF0PC5SPINJZ2Q2SAK2KGTN13GLN4BCGVETVLI5L152T'
    client_secret = 'HA2T3EADZZ3CUDB33ZNZL2DCC5CI1KXQE4H3ZVCBIZXHKDTF'
    ver = '20190421'
    category = "4bf58dd8d48988d17f941735"
    url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}&category={}'.format(
    client_id, client_secret, ver, lat, lon, radius, limit, category)


    results= requests.get(url).json()
    response = results['response']
    items = response['groups'][0]['items'][0]['venue']
    response['groups'][0]['items'][0]['venue']

    len(response['groups'][0]['items'])

    items = response['groups'][0]['items']
    lst=[]
    for item in items:
        venue = item['venue']
        try:
            name = venue['name']
            ID = venue['id']
            lat = venue['location']['lat']
            lon = venue['location']['lng']
            city = venue['location']['city']
            adress = venue['location']['address']
            kind = venue['categories'][0]['name']
            short_kind = venue['categories'][0]['shortName']
        except KeyError:
            pass


        lst.append([name, ID, lat, lon, city, adress, kind, short_kind])

    df = pd.DataFrame(lst)
    df.columns=['name', 'id', 'lat', 'lon', 'city', 'address', 'kind', 'short_kind']
    return (df)

# %%
client_id = 'W0NOIF0PC5SPINJZ2Q2SAK2KGTN13GLN4BCGVETVLI5L152T'
client_secret = 'HA2T3EADZZ3CUDB33ZNZL2DCC5CI1KXQE4H3ZVCBIZXHKDTF'
ver = '20190421'
category = "4bf58dd8d48988d17f941735"
lat = 52.276753
lon = 20.948055
radius=500
limit=100
url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
client_id, client_secret, ver, lat, lon, radius, limit)


results= requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '5ccf4aae6a607121248d0c0b'},
#  'response': {'headerLocation': 'Słodowiec',
#   'headerFullLocation': 'Słodowiec, Warsaw',
#   'headerLocationGranularity': 'neighborhood',
#   'totalResults': 5,
#   'suggestedBounds': {'ne': {'lat': 52.2812530045, 'lng': 20.955396042779643},
#    'sw': {'lat': 52.2722529955, 'lng': 20.940713957220357}},
#   'groups': [{'type': 'Recommended Places',
#     'name': 'recommended',
#     'items': [{'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '557ef6c3498e07d3e3bb30de',
#        'name': 'WakeCup Cafe',
#        'location': {'address': 'Al. Zjednoczenia 1',
#         'crossStreet': 'Żeromskiego',
#         'lat': 52.27706537130918,
#         'lng': 20.94682918511807,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 52.27706537130918,
#           'lng': 20.94682918511807}],
#         'distance': 90,
#         'cc': 'PL',
#         'city': 'Warszawa',
#         'state': 'Województwo mazowieckie',
#         'country': 'Polska',
#         'formattedAddress': ['Al. Zjednoczenia 1 (Żeromskiego)',
#          'Warszawa',
#          'Polska']},
#        'categories': [{'id': '4bf58dd8d48988d16d941735',
#          'name': 'Café',
#          'pluralName': 'Cafés',
#          'shortName': 'Café',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-557ef6c3498e07d3e3bb30de-0'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4e25f1ffcc3fd40fdb752a27',
#        'name': 'Plac Konfederacji',
#        'location': {'address': 'Plac Konfederacji',
#         'lat': 52.27964584263654,
#         'lng': 20.94665765762329,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 52.27964584263654,
#           'lng': 20.94665765762329}],
#         'distance': 335,
#         'postalCode': '01-817',
#         'cc': 'PL',
#         'city': 'Warszawa',
#         'state': 'Województwo mazowieckie',
#         'country': 'Polska',
#         'formattedAddress': ['Plac Konfederacji',
#          '01-817 Warszawa',
#          'Polska']},
#        'categories': [{'id': '4bf58dd8d48988d163941735',
#          'name': 'Park',
#          'pluralName': 'Parks',
#          'shortName': 'Park',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/park_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4e25f1ffcc3fd40fdb752a27-1'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '500c0505e4b02b2a7f99f086',
#        'name': 'Lukullus',
#        'location': {'lat': 52.2760176457318,
#         'lng': 20.950287106250922,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 52.2760176457318,
#           'lng': 20.950287106250922}],
#         'distance': 172,
#         'cc': 'PL',
#         'country': 'Polska',
#         'formattedAddress': ['Polska']},
#        'categories': [{'id': '4bf58dd8d48988d16a941735',
#          'name': 'Bakery',
#          'pluralName': 'Bakeries',
#          'shortName': 'Bakery',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bakery_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-500c0505e4b02b2a7f99f086-2'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '52c172a911d23a8f7cec056c',
#        'name': 'Cafe de la Poste',
#        'location': {'address': 'Efraima Schroegera 72',
#         'crossStreet': 'Plac Konfederacji',
#         'lat': 52.27994279764028,
#         'lng': 20.945982803046544,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 52.27994279764028,
#           'lng': 20.945982803046544}],
#         'distance': 382,
#         'cc': 'PL',
#         'city': 'Warszawa',
#         'state': 'Województwo mazowieckie',
#         'country': 'Polska',
#         'formattedAddress': ['Efraima Schroegera 72 (Plac Konfederacji)',
#          'Warszawa',
#          'Polska']},
#        'categories': [{'id': '4bf58dd8d48988d16d941735',
#          'name': 'Café',
#          'pluralName': 'Cafés',
#          'shortName': 'Café',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-52c172a911d23a8f7cec056c-3'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '54dc7142498e2dfd2bb72933',
#        'name': 'Roślina Cafe',
#        'location': {'address': 'Schroegera 80',
#         'lat': 52.28032306689834,
#         'lng': 20.94455721347905,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 52.28032306689834,
#           'lng': 20.94455721347905}],
#         'distance': 463,
#         'cc': 'PL',
#         'country': 'Polska',
#         'formattedAddress': ['Schroegera 80', 'Polska']},
#        'categories': [{'id': '4bf58dd8d48988d16d941735',
#          'name': 'Café',
#          'pluralName': 'Cafés',
#          'shortName': 'Café',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-54dc7142498e2dfd2bb72933-4'}]}]}}

# %%
warsaw = folium.Map(location = [lat_center, lon_center], zoom_start = 13)


for lat, lon, name in zip(t_full['lat'], t_full['lon'], t_full['teatr']):
    folium.CircleMarker([lat, lon], radius = 5, fill=True, fill_color='orange', 
                        color = 'red', popup=name).add_to(warsaw)
    
warsaw
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
db_gen(52.2373039, 21.0328462)
# Out:
#                               name                        id        lat  \
# 0                    Teatr Ateneum  4bf959fd4a67c92857ac26cf  52.237345
# 1                Nadwiślański Świt  54ea2405498e0dbe7ccd6106  52.238024
# 2                 Schody Nad Wisłą  4db5fc380437fa536a4d325e  52.239520
# 3                      Mr. Pancake  4dad9714043718a63e35180a  52.236380
# 4                     The Cool Cat  5628fa77498e0749c5a9a9df  52.235178
# 5             Plac Zabaw nad Wisłą  5575a906498ed7be503ee8e1  52.239288
# 6                            BarKa  518e7f3e498efd1f9f16e4ed  52.239456
# 7           Kufle i Kapsle Powiśle  5b46fc5b9411f2002cadba82  52.236263
# 8                       CREPE CAFE  4fc0a8ffe4b0b469de7df4a1  52.238013
# 9             Heritage Shop & Wine  50eb0956e4b0a5a082658641  52.237504
# 10                Warszawa Powiśle  4ba61e81f964a520fe3439e3  52.234072
# 11           Mei Korean Restaurant  532c7fe3498ed909f5484d47  52.234142
# 12  LAS (Lokalna Atrakcja Stolicy)  5b6b2443491be70039c247ee  52.236191
# 13                        PRZY3MAJ  578501fe498e08fd292a9d59  52.233937
# 14                  Park Odkrywców  4e21f829d4c0d32590f4e862  52.241209
# 15                    Don Sandwich  56964880498ee045faddc885  52.234094
# 16                Galeria Wypieków  4d2f32b3b97cb1f7e61e9648  52.237627
# 17              Makkaron Pasta Bar  4d5d01a8f57ca09003fd84e0  52.235091
# 18                       Food Port  5543acfc498e2c25c5f852d7  52.236032
# 19                         VIADUCT  51643804e4b0c45173f514c7  52.234141
# 24  21.029920  Warszawa                            Al. 3 Maja
# 25  21.027861  Warszawa                             Tamka 13A
# 26  21.025704  Warszawa                              Tamka 29
# 27  21.033072  Warszawa                              Solec 38
# 28  21.025629  Warszawa                              Tamka 30
# 29  21.025809  Warszawa                              Tamka 30
# 30  21.035908  Warszawa                                 Solec
# 31  21.034363  Warszawa                             Solec 81b
# 32  21.033306  Warszawa            Filar mostu Poniatowskiego
# 33  21.030561  Warszawa            Filar mostu Poniatowskiego
# 34  21.033455  Warszawa  Bulwar Bohdana Grzymały Siedleckiego
# 35  21.027738  Warszawa  Bulwar Bohdana Grzymały Siedleckiego
# 36  21.034022  Warszawa  Bulwar Bohdana Grzymały Siedleckiego
# 37  21.028387  Warszawa                       ul. Dobra 22/24
# 38  21.030613  Warszawa                            Al. 3 Maja
# 39  21.032351  Warszawa                            Al. 3 Maja
# 40  21.035027  Warszawa                            Al. 3 Maja
# 41  21.031280  Warszawa                                 Tamka
# 42  21.030841  Warszawa                         Kruczkowkiego
#
#                            kind        short_kind
# 0                       Theater           Theater
# 1                    Restaurant        Restaurant
# 2                    Restaurant        Restaurant
# 3                      Creperie          Creperie
# 4              Asian Restaurant             Asian
# 5              Asian Restaurant             Asian
# 6               Other Nightlife         Nightlife
# 7                           Pub               Pub
# 8                          Café              Café
# 9                 Deli / Bodega     Deli / Bodega
# 10                          Bar               Bar
# 11            Korean Restaurant            Korean
# 12            Polish Restaurant            Polish
# 13                       Bistro            Bistro
# 14                         Park              Park
# 15                         Park              Park
# 16                       Bakery            Bakery
# 17           Italian Restaurant           Italian
# 18           Italian Restaurant           Italian
# 19                  Pizza Place             Pizza
# 20            Food & Drink Shop      Food & Drink
# 21                  Pizza Place             Pizza
# 22                  Pizza Place             Pizza
# 23                  Pizza Place             Pizza
# 24                          Bar               Bar
# 25                    Gastropub         Gastropub
# 26      Health & Beauty Service   Health & Beauty
# 27         Gym / Fitness Center     Gym / Fitness
# 28                       Hostel            Hostel
# 29                       Hostel            Hostel
# 30                  Supermarket       Supermarket
# 31                 Liquor Store      Liquor Store
# 32                          Pub               Pub
# 33                          Pub               Pub
# 34                       Lounge            Lounge
# 35                       Lounge            Lounge
# 36                       Lounge            Lounge
# 37            French Restaurant            French
# 38                          Bar               Bar
# 39                          Bar               Bar
# 40                          Bar               Bar
# 41                Metro Station             Metro
# 42  Eastern European Restaurant  Eastern European

# %%
venlist = []
for lat, lon, name in zip(t_full['lat'], t_full['lon'],t_full['teatr']):
    try: 
        venues = db_gen(lat, lon, radius = 500)
        print("OK " + name + " " + str(lat) + " " + str(lon))
        venlist.append({'name': name, 'venues': venues['short_kind'].value_counts()})
    except: pass; print("error " + name + " " + str(lat) + " " + str(lon)); venlist.append({'name': name, 'none': 0})
# Out:
# OK Mazowiecki Teatr Muzyczny Operetka 52.2767531 20.9480547
# OK Nowy Teatr 52.2052251 21.0199031
# OK Och-Teatr 52.214206 20.980168
# OK Stara ProchOFFnia 52.2520335 21.0118501
# OK Studio Buffo 52.2281469 21.026145
# OK Studium Teatralne 52.2504595 21.0509099
# OK Teatr 6. piętro 52.2317616 21.0061014
# OK Teatr Ateneum 52.2373039 21.0328462
# error Teatr Baj 52.2523563 21.034443
# OK Teatr Bajka 52.2358644 21.0086243
# OK Teatr „Capitol” 52.2412061 21.0030915
# error Teatr Collegium Nobilium 52.2486241 21.0079363
# OK Teatr Dramatyczny m.st. Warszawy 52.231311 21.007571
# OK Teatr Druga Strefa 52.1862106 21.0054782
# OK Teatr Guliwer 52.203143 21.019801
# OK Teatr IMKA 52.2284013 21.0261534
# OK Teatr Kamienica 52.2432744 20.9984949
# OK Teatr Komedia 52.2689536 20.9786279
# OK Teatr Kwadrat 52.2358644 21.0086243
# OK Teatr Lalka 52.2328725 21.0065461
# OK Teatr Małego Widza 52.249697 21.0139989
# OK Teatr Montownia 52.2284013 21.0261534
# OK Teatr Muzyczny „Roma” 52.227404 21.007815
# OK Teatr na Woli 52.2290795 20.9704782
# OK Teatr Narodowy 52.242613 21.009646
# OK Teatr Ochoty 52.2171578 20.9890375
# OK Teatr „Polonia” 52.22376 21.015918
# OK Teatr Polski 52.2385255 21.0197007
# OK Teatr Powszechny 52.2471671 21.0481498
# OK Teatr Praga 52.2591534 21.036559
# OK Teatr Praski 52.2504689 21.0383497
# OK Teatr Rampa 52.2726599 21.049511
# OK Teatr Rozmaitości 52.214898 21.021133
# OK Teatr Sabat 52.233856 21.0208001
# OK Teatr Scena Prezentacje 52.2323107 20.991985
# OK Teatr Staromiejski 52.249534 21.0135665
# OK Teatr Studio 52.2324841 21.0067814
# OK Teatr Syrena 52.2163929 21.02207
# OK Teatr Wielki - Opera Narodowa 52.2435324 21.0106636
# error Teatr WARSawy 52.2525671 21.0084412
# error Teatr Wolandejski 52.1566737 21.0412423
# OK Teatr Współczesny 52.2189832 21.0171886
# OK Teatr Za Daleki 52.1614393 21.026836
# OK Teatr Żydowski 52.242686 21.0053911
# OK Warszawska Opera Kameralna 52.2440049 20.9972748

# %%
t1 = pd.DataFrame(venlist[1]['venues']).transpose().rename(index={"short_kind": venlist[1]['name']})
t2 = pd.DataFrame(venlist[2]['venues']).transpose().rename(index={"short_kind": venlist[2]['name']})

t1.append(t2, sort=True)
df = pd.DataFrame()
for theatre in venlist:
    try:
        temp = pd.DataFrame(theatre['venues']).transpose().rename(index={"short_kind": theatre['name']})
        df = df.append(temp)
    except:
        pass
    
for col in df:
    df[col] = pd.to_numeric(df[col], errors='coerce').fillna(0)
    
df['venue_sum'] = df.sum(axis=1)
# Out:
# /home/lemur/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py:6692: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   sort=sort)

# %%
import statsmodels.api as sm
y= merged['rating']
X = sm.add_constant(merged[['venue_sum']])
model2 = sm.OLS(y.astype(float), X.astype(float)).fit()
model2.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 rating   R-squared:                       0.029
# Model:                            OLS   Adj. R-squared:                  0.004
# Method:                 Least Squares   F-statistic:                     1.159
# Date:                Sun, 05 May 2019   Prob (F-statistic):              0.288
# Time:                        23:26:30   Log-Likelihood:                -44.981
# No. Observations:                  41   AIC:                             93.96
# Df Residuals:                      39   BIC:                             97.39
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          4.2221      0.234     18.006      0.000       3.748       4.696
# venue_sum      0.0042      0.004      1.077      0.288      -0.004       0.012
# ==============================================================================
# Omnibus:                       86.254   Durbin-Watson:                   2.079
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1750.412
# Skew:                          -5.427   Prob(JB):                         0.00
# Kurtosis:                      33.113   Cond. No.                         121.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
import statsmodels.api as sm
y= merged['user_ratings_total']
X = sm.add_constant(merged[['venue_sum']])
model3 = sm.OLS(y.astype(float), X.astype(float)).fit()
model3.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:     user_ratings_total   R-squared:                       0.069
# Model:                            OLS   Adj. R-squared:                  0.045
# Method:                 Least Squares   F-statistic:                     2.888
# Date:                Sun, 05 May 2019   Prob (F-statistic):             0.0972
# Time:                        23:27:46   Log-Likelihood:                -345.28
# No. Observations:                  41   AIC:                             694.6
# Df Residuals:                      39   BIC:                             698.0
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        323.9605    355.686      0.911      0.368    -395.482    1043.403
# venue_sum     10.0808      5.932      1.699      0.097      -1.918      22.080
# ==============================================================================
# Omnibus:                       29.958   Durbin-Watson:                   1.856
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               59.458
# Skew:                           2.015   Prob(JB):                     1.23e-13
# Kurtosis:                       7.308   Cond. No.                         121.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
def collect_more(init_lat, init_lon, n=100):
    df1 = db_gen(init_lat, init_lon)
    
    i=0
    
    while (i < n): 
        i=i+1
        clear_output(wait=True)
        print(str(100*(i)/n), "%")
        try:
            sample = df1.sample(1)
            new_lat = sample['lat'].tolist()[0]
            new_lon = sample['lon'].tolist()[0]
            df2 = db_gen(new_lat, new_lon)
            df1 = df1.append(df2)
            df1.drop_duplicates('id', inplace=True)
        except: print("error, continue"); continue    
    return(df1)

# %%
lat_center, lon_center = 52.225665764, 21.003833318
places = collect_more(lat_center, lon_center, n=50)
places
# Out:
# 100.0 %
#                                     name                        id        lat  \
# 0   Hampton by Hilton Warsaw City Centre  53a45b1d498e35d5abaf3c5e  52.225347
# 1                            Bar Pacyfik  58ff9dd3b9ac3810e95fdbe2  52.224703
# 2     Marriott Warsaw - Executive Lounge  4eda4e29be7be28337954c8c  52.227947
# 3                         Marriot Skybar  554ea454498e220a445844ca  52.227817
# 4                        Marriott Warsaw  4b6c32f3f964a52006292ce3  52.227688
# 5                                Mandala  4bb3ca5414cfd13a3b8e16ab  52.223658
# 6                             Teatr Roma  4ca21ef554c8a1cd4af9ad4b  52.227756
# 7                       Panorama Sky Bar  4c3787832c8020a193318900  52.227819
# 8                               Katmandu  4c039d549a7920a14c17d079  52.226146
# 9                             Flambéeria  541dbe49498e5719ff9d20c2  52.224518
# 10                               Vapiano  4fda26aee4b013d81a7dd72d  52.228271
# 11                 Egurrola Dance Studio  4c1892aefe5a76b0a5390215  52.227045
# 12                                 Sofra  505ef581e4b04c6cd204f6cb  52.223168
# 13                   Youmiko Vegan Sushi  56a8c14b498e4b91ea4ea08e  52.225470
# 14                         Izakaya Izumi  519fc791498e25e78bd38b0b  52.228072
# 15           Holmes Place Hotel Marriott  502e1758e4b06e61e137da57  52.227881
# 16                          Tłusty Kotek  574089a0498e91e76faa966e  52.224793
# 17                                 Cophi  544f620d498e767f77b9f541  52.225585
# 46  21.024200  Warszawa  SomePlace Else, Warsaw, Bolesława Prusa 2, War...
# 51  21.026245  Warszawa                                Ul. Konopnieckiej 6
# 55  21.022131  Warszawa                              plac Trzech Krzyży 16
# 57  21.023572  Warszawa                                       Żurawia 6/12
# 60  21.018664    Warsaw                                          Zurawia 6
# 63  21.023444  Warszawa                               Aleje Ujazdowskie 22
# 64  21.026367  Warszawa                                     Konopnickiej 6
# 65  21.024299  Warszawa                                     Konopnickiej 6
# 66  21.025667  Warszawa                                        Wiejska 12a
# 68  21.024069  Warszawa                                          Piękna 18
# 70  21.027094  Warszawa                                           Książęca
#
#                            kind         short_kind
# 0                         Hotel              Hotel
# 1                         Hotel              Hotel
# 2                     Hotel Bar          Hotel Bar
# 3                     Hotel Bar          Hotel Bar
# 4                         Hotel              Hotel
# 5             Indian Restaurant             Indian
# 6                       Theater            Theater
# 7                     Hotel Bar          Hotel Bar
# 8             Indian Restaurant             Indian
# 9                        Bistro             Bistro
# 10           Italian Restaurant            Italian
# 11                 Dance Studio       Dance Studio
# 12     Mediterranean Restaurant      Mediterranean
# 13             Sushi Restaurant              Sushi
# 14          Japanese Restaurant           Japanese
# 15         Gym / Fitness Center      Gym / Fitness
# 16               Ice Cream Shop          Ice Cream
# 17                         Café               Café
# 18                  Pizza Place              Pizza
# 19          American Restaurant           American
# 20                          Bar                Bar
# 21                       Bakery             Bakery
# 22                       Bakery             Bakery
# 23                       Bakery             Bakery
# 24                       Bakery             Bakery
# 25   Modern European Restaurant    Modern European
# 26           Chinese Restaurant            Chinese
# 27               History Museum     History Museum
# 28                 Cupcake Shop           Cupcakes
# 29                          Gym                Gym
# ..                          ...                ...
# 97                     Wine Bar           Wine Bar
# 98                  Bus Station        Bus Station
# 95                   Restaurant         Restaurant
# 97            Convenience Store  Convenience Store
# 5            Dim Sum Restaurant            Dim Sum
# 8   Eastern European Restaurant   Eastern European
# 9   Eastern European Restaurant   Eastern European
# 16                         Café               Café
# 21           Italian Restaurant            Italian
# 29                  Coffee Shop        Coffee Shop
# 44                        Plaza              Plaza
# 47                        Diner              Diner
# 10                        Hotel              Hotel
# 14              Thai Restaurant               Thai
# 23             Sculpture Garden          Sculpture
# 25                      Theater            Theater
# 35           Spanish Restaurant            Spanish
# 43                Women's Store      Women's Store
# 45             Department Store   Department Store
# 46                 Cocktail Bar           Cocktail
# 51  Eastern European Restaurant   Eastern European
# 55                  Coffee Shop        Coffee Shop
# 57                       Bistro             Bistro
# 60           Seafood Restaurant            Seafood
# 63           Mexican Restaurant            Mexican
# 64                      Theater            Theater
# 65                      Theater            Theater
# 66               Breakfast Spot          Breakfast
# 68                         Café               Café
# 70                         Park               Park
#
# [585 rows x 8 columns]

# %%
warsaw = folium.Map(location = [lat_center, lon_center], zoom_start = 13)


for lat, lon, short_kind in zip(places['lat'], places['lon'], places['short_kind']):
    folium.CircleMarker([lat, lon], radius = 5, fill=True, fill_color='orange', 
                        color = 'red', popup=short_kind).add_to(warsaw)
    
warsaw
